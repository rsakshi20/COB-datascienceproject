# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
path=''
dataset=pd.read_csv(os.path.join(path, '/content/dataset - netflix1 (3).csv'))

# %%
dataset.sort_values('release_year')
dataset.head(20)
# Out:
#      show_id     type                                             title  \
# 421    s4251  TV Show                 Pioneers: First Women Filmmakers*
# 1489   s1700    Movie                                   White Christmas
# 1935   s2369    Movie                                     Cairo Station
# 1936   s2370    Movie                                       Dark Waters
# 1941   s2376    Movie                                   The Blazing Sun
# 4644   s6432    Movie                             Cat on a Hot Tin Roof
# 4918   s6785    Movie                                  Forbidden Planet
# 4970   s6854    Movie                                              Gigi
# 5264   s7220    Movie                           Know Your Enemy - Japan
# 5320   s7295    Movie                                Let There Be Light
# 5545   s7576    Movie                          Nazi Concentration Camps
# 5679   s7744  TV Show               Pioneers of African-American Cinema
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
dataset.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
dataset.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
dataset=dataset.dropna()

# %% [markdown]
# outliners

# %%
sns.boxplot(data = dataset['release_year'])
plt.show()

# %%
dataset=dataset[dataset['release_year']<2001]

# %%
sns.boxplot(data = dataset['release_year'])
plt.show()

# %%
dataset=dataset[dataset['release_year']<1959]

# %%
sns.boxplot(data = dataset['release_year'])
plt.show()
